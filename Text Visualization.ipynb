# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(u'Apple is going to build a U.K. factory for $6 million.')
displacy.render(doc, style='dep', jupyter=True, options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0b7f228da98b4c34a8d7e6a4bfe91a13-0" class="displacy" width="1010" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">U.K.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">factory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-0" stroke-width="2px" d="M70,162.0 C70,82.0 200.0,82.0 200.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,164.0 L62,152.0 78,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-1" stroke-width="2px" d="M150,162.0 C150,122.0 195.0,122.0 195.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,164.0 L142,152.0 158,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-2" stroke-width="2px" d="M310,162.0 C310,122.0 355.0,122.0 355.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,164.0 L302,152.0 318,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-3" stroke-width="2px" d="M230,162.0 C230,82.0 360.0,82.0 360.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M360.0,164.0 L368.0,152.0 352.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-4" stroke-width="2px" d="M470,162.0 C470,82.0 600.0,82.0 600.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,164.0 L462,152.0 478,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-5" stroke-width="2px" d="M550,162.0 C550,122.0 595.0,122.0 595.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,164.0 L542,152.0 558,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-6" stroke-width="2px" d="M390,162.0 C390,42.0 605.0,42.0 605.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M605.0,164.0 L613.0,152.0 597.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-7" stroke-width="2px" d="M390,162.0 C390,2.0 690.0,2.0 690.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0b7f228da98b4c34a8d7e6a4bfe91a13-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M690.0,164.0 L698.0,152.0 682.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0b7f228da98b4c34a8d7

# %%
for token in doc:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{7}} {spacy.explain(token.dep_)}')
# Out:
# Apple      PROPN   nsubj   nominal subject
# is         AUX     aux     auxiliary
# going      VERB    ROOT    root
# to         PART    aux     auxiliary
# build      VERB    xcomp   open clausal complement
# a          DET     det     determiner
# U.K.       PROPN   compound compound
# factory    NOUN    dobj    direct object
# for        ADP     prep    prepositional modifier
# $          SYM     quantmod modifier of quantifier
# 6          NUM     compound compound
# million    NUM     pobj    object of preposition
# .          PUNCT   punct   punctuation

# %%
# doc = nlp(u'This is a sentence.')
# displacy.serve(doc, style='dep')

# %%
text = """In ancient Rome, some neighbors live in three adjacent houses. In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus. A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom. One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates). One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero. Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin)."""
doc = nlp(text)
sentence_spans = list(doc.sents)
sentence_spans
# displacy.render(sentence_spans, style="dep",options={'distance': 50})
# Out:
# [In ancient Rome, some neighbors live in three adjacent houses.,
#  In the center is the house of Senex, who lives there with wife Domina, son Hero, and several slaves, including head slave Hysterium and the musical's main character Pseudolus.,
#  A slave belonging to Hero, Pseudolus wishes to buy, win, or steal his freedom.,
#  One of the neighboring houses is owned by Marcus Lycus, who is a buyer and seller of beautiful women; the other belongs to the ancient Erronius, who is abroad searching for his long-lost children (stolen in infancy by pirates).,
#  One day, Senex and Domina go on a trip and leave Pseudolus in charge of Hero.,
#  Hero confides in Pseudolus that he is in love with the lovely Philia, one of the courtesans in the House of Lycus (albeit still a virgin).]

# %%
from IPython.core.display import display, HTML
doc1 = nlp("This is a sentence.")
doc2 = nlp("This is another sentence.")
html = displacy.render([doc1, doc2], style="dep", page=True)
# html = displacy.render(doc, style="dep")
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c733233477ad4e95939ebf340a89ca2f-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c733233477ad4e95939ebf340a89ca2f-1" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">sentence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-1-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-1-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c733233477ad4e95939ebf340a89ca2f-1-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c733233477ad4e95939ebf340a89ca2f-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html>

# %%
doc = nlp("Rats are various medium-sized, long-tailed rodents.")
html = displacy.render(doc, style="dep", options={'distance': 80})
display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a8316a0051984cd692a7f1d7a85e38e0-0" class="displacy" width="690" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Rats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">various</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">medium-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">sized,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">long-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">tailed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">rodents.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-0" stroke-width="2px" d="M70,162.0 C70,122.0 115.0,122.0 115.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,164.0 L62,152.0 78,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-1" stroke-width="2px" d="M230,162.0 C230,42.0 605.0,42.0 605.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230,164.0 L222,152.0 238,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-2" stroke-width="2px" d="M310,162.0 C310,122.0 355.0,122.0 355.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,164.0 L302,152.0 318,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-3" stroke-width="2px" d="M390,162.0 C390,82.0 600.0,82.0 600.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390,164.0 L382,152.0 398,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-4" stroke-width="2px" d="M470,162.0 C470,122.0 515.0,122.0 515.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,164.0 L462,152.0 478,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-5" stroke-width="2px" d="M550,162.0 C550,122.0 595.0,122.0 595.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,164.0 L542,152.0 558,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a8316a0051984cd692a7f1d7a85e38e0-0-6" stroke-width="2px" d="M150,162.0 C150,2.0 610.0,2.0 610.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a8316a0051984cd692a7f1d7a85e38e0-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610.0,164.0 L618.0,152.0 602.0,152.0" fill="currentColor"/>
# </g>
# </svg>

# %%
from pathlib import Path

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million. '
         u'By contrast, Sony sold only 7 thousand Walkman music players.')
html = displacy.render(doc, style="dep", options={"compact": True, "bg": "#09a3d5",
                                           'distance': 50,"color": "white",
                                           "font": "Source Sans Pro"})

display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c891ccfcc5b94eecb7d4530335c5be78-0" class="displacy" width="1400" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">last</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">quarter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">sold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">nearly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">20</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">thousand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">iPods</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">profit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="700">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="700">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">million.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="900">By</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">contrast,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1000">Sony</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">sold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1200">thousand</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1200">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Walkman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1300">music</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">players.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c891ccfcc5b94eecb7d4530335c5be78-0-0" stroke-width="2px" d="M62,102.0 62,68.66666666666666 300.0,68.66666666666666 300.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c891ccfcc5b94eecb7d4530335c5be78-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c891ccfcc5b94eecb7d4530335c5be78-0-1" stroke-width="2px" d="M112,102.0 112,85.33333333333333 194.0,85.33333333333333 194.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c891ccfcc5b94eecb7d4530335c5be78-0-1" class="displacy-label" startOffset="50%" side="le

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million.')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>

# %%
doc = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million. '
         u'By contrast, Sony sold only 7 thousand Walkman music players.')


displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# . By contrast,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     only 7 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Walkman music players.</div></span>

# %%
doc2 = nlp(u'Over the last quarter Apple sold nearly 20 thousand iPods for a profit of $6 million. '
         u'By contrast, my kids sold a lot of lemonade.')

for sent in doc2.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx, style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the last quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 thousand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# .</div></span>
# By contrast, my kids sold a lot of lemonade.

# %%
options = {'ents': ['ORG', 'PRODUCT']}

displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over the last quarter
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold nearly 20 thousand
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of $6 million. By contrast,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold only 7 thousand Walkman music players.</div></span>

# %%
colors = {'ORG': 'linear-gradient(90deg, #aa9cfc, #fc9ce7)', 'PRODUCT': 'radial-gradient(yellow, green)'}

options = {'ents': ['ORG', 'PRODUCT'], 'colors':colors}

displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Over the last quarter
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold nearly 20 thousand
# <mark class="entity" style="background: radial-gradient(yellow, green); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for a profit of $6 million. By contrast,
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sold only 7 thousand Walkman music players.</div></span>

# %%
text = "When Sebastian Thrun started working on self-driving cars at Google in 2007, few people outside of the company took him seriously."
doc = nlp(text)
html = displacy.render(doc, style="ent")

display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sebastian Thrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  started working on self-driving cars at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , few people outside of the company took him seriously.</div>

# %%
colors = {"ORG": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
options = {"ents": ["ORG"], "colors": colors}
html=  displacy.render(doc, style="ent", options=options)

display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">When Sebastian Thrun started working on self-driving cars at
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in 2007, few people outside of the company took him seriously.</div>

# %%
doc = nlp("This is a sentence about Google.")
doc.user_data["title"] = "This is a title"
html = displacy.render(doc, style="ent")

display(HTML(html))
# Out:
# <h2 style="margin: 0">This is a title</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">This is a sentence about
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div>

# %%
ex = [{"text": "But Google is starting from behind.",
       "ents": [{"start": 4, "end": 10, "label": "ORG"}],
       "title": None}]
html = displacy.render(ex, style="ent", manual=True)
display(HTML(html))
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">But
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is starting from behind.</div>

# %%
doc = nlp('ستقوم شركة مرسيدس بشراء شركة كرايسلر بمبلغ 5 مليون دولار')
displacy.render(doc, style='dep', jupyter=True, options={'distance': 80})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="2b264c286bcf42ec9f5f966463c2c982-0" class="displacy" width="850" height="297.0" direction="ltr" style="max-width: none; height: 297.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ستقوم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="130">شركة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="130">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="210">مرسيدس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">بشراء</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="370">شركة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">كرايسلر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">بمبلغ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="690">مليون</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="207.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">دولار</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-0" stroke-width="2px" d="M70,162.0 C70,122.0 115.0,122.0 115.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,164.0 L62,152.0 78,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-1" stroke-width="2px" d="M150,162.0 C150,2.0 530.0,2.0 530.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">csubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M150,164.0 L142,152.0 158,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-2" stroke-width="2px" d="M230,162.0 C230,122.0 275.0,122.0 275.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M230,164.0 L222,152.0 238,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-3" stroke-width="2px" d="M150,162.0 C150,82.0 280.0,82.0 280.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M280.0,164.0 L288.0,152.0 272.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-4" stroke-width="2px" d="M150,162.0 C150,42.0 365.0,42.0 365.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M365.0,164.0 L373.0,152.0 357.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-5" stroke-width="2px" d="M390,162.0 C390,122.0 435.0,122.0 435.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M435.0,164.0 L443.0,152.0 427.0,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-6" stroke-width="2px" d="M630,162.0 C630,82.0 760.0,82.0 760.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M630,164.0 L622,152.0 638,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-7" stroke-width="2px" d="M710,162.0 C710,122.0 755.0,122.0 755.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M710,164.0 L702,152.0 718,152.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-2b264c286bcf42ec9f5f966463c2c982-0-8" stroke-width="2px" d="M550,162.0 C550,42.0 765.0,42.0 765.0,162.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-2b264c286bcf42ec9f5f966463c2c982-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M765.0,164.0 L773.0,152.0 757.0,152.0"

# %%
text = """
و عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232 هـ أي (بعد 847م). يعتبر من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها كتاب المختصر في حساب الجبر والمقابلة الذي يعد أهم كتبه.

ترجم الكتابَ إلى اللغة اللاتينية حوالي عام 1145 م العالم روبرت مِن تشستر. دخلت على إثر ذلك كلمات مثل الجبر Algebra والصفر Zero إلى اللغات اللاتينية وترجمه بعد ذلك بقليل جيراردو الكريموني الساكن في طليطلة، متبوعا في ذلك بترجمة ثالثة قام بها الإيطالي غيوم دي لونا. استُعملت ترجمة روبرت مِن تشستر الكتاب الرئيسي في الرياضيات إلى حدود القرن السادس عشر في الجامعات الأوروبية.

"""
doc = nlp(text)
sentence_spans = list(doc.sents)
html = displacy.render(sentence_spans, style="dep",options={'distance': 50})



display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1ec23651fc1749aa8c2e1db3a15749c3-0" class="displacy" width="700" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="100">و</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="100">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">عبد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">الله</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">محمد</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">بن</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">موسى</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">الخوارزمي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">عالم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">رياضيات</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">وفلك</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">وجغرافيا</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">مسلم.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-0" stroke-width="2px" d="M70,102.0 C70,77.0 85.0,77.0 85.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,104.0 L62,92.0 78,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-1" stroke-width="2px" d="M120,102.0 C120,52.0 240.0,52.0 240.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M120,104.0 L112,92.0 128,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-2" stroke-width="2px" d="M170,102.0 C170,77.0 185.0,77.0 185.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,104.0 L162,92.0 178,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-3" stroke-width="2px" d="M220,102.0 C220,77.0 235.0,77.0 235.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,104.0 L212,92.0 228,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-4" stroke-width="2px" d="M270,102.0 C270,27.0 445.0,27.0 445.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,104.0 L262,92.0 278,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-5" stroke-width="2px" d="M320,102.0 C320,52.0 440.0,52.0 440.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320,104.0 L312,92.0 328,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-6" stroke-width="2px" d="M370,102.0 C370,77.0 385.0,77.0 385.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,104.0 L362,92.0 378,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-7" stroke-width="2px" d="M420,102.0 C420,77.0 435.0,77.0 435.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1ec23651fc1749aa8c2e1db3a15749c3-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</

# %%
doc1 = nlp("هذه هي الجملة الأولي")
doc2 = nlp("هذه هي الجملة التالية لها ")
html = displacy.render([doc1, doc2], style="dep", page=True)
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="01efde19fe2e45bebc032d232ae173ed-0" class="displacy" width="750" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">هذه</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">هي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">الجملة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">الأولي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-0-0" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-0-1" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-0-2" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
# </svg>
# </figure>
#
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="01efde19fe2e45bebc032d232ae173ed-1" class="displacy" width="925" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">هذه</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">هي</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">الجملة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">التالية</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">لها</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-1-0" stroke-width="2px" d="M70,352.0 C70,2.0 750.0,2.0 750.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-1-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-1-1" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-1-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-1-2" stroke-width="2px" d="M420,352.0 C420,177.0 740.0,177.0 740.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-1-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-01efde19fe2e45bebc032d232ae173ed-1-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-01efde19fe2e45bebc032d232ae173ed-1-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html>

# %%
from pathlib import Path

# %%
doc = nlp(u'ستقوم شركة مرسيدس بشراء شركة كرايسلر بمبلغ 5 مليون دولار')

html = displacy.render(doc, style="dep", options={"compact": True, "bg": "#09a3d5",
                                           'distance': 50,"color": "white",
                                           "font": "Source Sans Pro"})


display(HTML(html))
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="1a86595d607144ff8bde8344775e035d-0" class="displacy" width="550" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: white; background: #09a3d5; font-family: Source Sans Pro; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ستقوم</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="100">شركة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">مرسيدس</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">بشراء</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">شركة</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">كرايسلر</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">بمبلغ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">مليون</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">دولار</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-0" stroke-width="2px" d="M62,102.0 62,93.66666666666667 91.0,93.66666666666667 91.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,104.0 L58,96.0 66,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-1" stroke-width="2px" d="M112,102.0 112,68.66666666666666 350.0,68.66666666666666 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">csubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M112,104.0 L108,96.0 116,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-2" stroke-width="2px" d="M162,102.0 162,93.66666666666667 191.0,93.66666666666667 191.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M162,104.0 L158,96.0 166,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-3" stroke-width="2px" d="M112,102.0 112,85.33333333333333 194.0,85.33333333333333 194.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M194.0,104.0 L198.0,96.0 190.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-4" stroke-width="2px" d="M112,102.0 112,77.0 247.0,77.0 247.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M247.0,104.0 L251.0,96.0 243.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-5" stroke-width="2px" d="M262,102.0 262,93.66666666666667 291.0,93.66666666666667 291.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M291.0,104.0 L295.0,96.0 287.0,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-6" stroke-width="2px" d="M412,102.0 412,85.33333333333333 494.0,85.33333333333333 494.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M412,104.0 L408,96.0 416,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-7" stroke-width="2px" d="M462,102.0 462,93.66666666666667 491.0,93.66666666666667 491.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,104.0 L458,96.0 466,96.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-1a86595d607144ff8bde8344775e035d-0-8" stroke-width="2px" d="M362,102.0 362,77.0 497.0,77.0 497.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-1a86595d607144ff8bde8344775e035d-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor"

# %%
doc = nlp(u'ستقوم شركة مرسيدس بشراء شركة كرايسلر بمبلغ 5 مليون دولار')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ستقوم شركة مرسيدس بشراء شركة كرايسلر بمبلغ
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  مليون دولار</div></span>

# %%
text = """
و عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك وجغرافيا مسلم. يكنى باسم الخوارزمي وأبي جعفر. قيل أنه ولد حوالي 164هـ 781م (وهو غير مؤكد) وقيل أنه توفي بعد 232 هـ أي (بعد 847م). يعتبر من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في بغداد وكسب ثقة الخليفة إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل فيها أكثر من سبعين جغرافيا. قبل وفاته في 850 م/232 هـ كان الخوارزمي قد ترك العديد من المؤلفات في علوم الرياضيات والفلك والجغرافيا ومن أهمها كتاب المختصر في حساب الجبر والمقابلة الذي يعد أهم كتبه.

ترجم الكتابَ إلى اللغة اللاتينية حوالي عام 1145 م العالم روبرت مِن تشستر. دخلت على إثر ذلك كلمات مثل الجبر Algebra والصفر Zero إلى اللغات اللاتينية وترجمه بعد ذلك بقليل جيراردو الكريموني الساكن في طليطلة، متبوعا في ذلك بترجمة ثالثة قام بها الإيطالي غيوم دي لونا. استُعملت ترجمة روبرت مِن تشستر الكتاب الرئيسي في الرياضيات إلى حدود القرن السادس عشر في الجامعات الأوروبية.

"""

doc = nlp(text)

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>و عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك وجغرافيا مسلم.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     يكنى
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  باسم الخوارزمي وأبي جعفر.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     قيل أنه ولد حوالي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  164هـ 781م (وهو غير مؤكد) وقيل
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     أنه توفي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  بعد
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     232 هـ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  أي (بعد
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     847
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# م). يعتبر من أوائل علماء الرياضيات المسلمين حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره. اتصل بالخليفة العباسي المأمون وعمل في بيت الحكمة في بغداد
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     وكسب ثقة الخليفة
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     فيها أكثر
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  من سبعين جغرافيا.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     قبل
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  وفاته في
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     850
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  م/232 هـ كان الخوارزمي قد ترك العديد من المؤلفات في
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     علوم الرياضيات والفلك
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  والجغرافيا
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ومن
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  أهمها كتاب المختصر في حساب الجبر والمقابلة
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الذي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  يعد أهم كتبه.<br><br>ترجم
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الكتابَ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  إلى اللغة اللاتينية حوالي عام
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1145
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  م العالم روبرت مِن تشستر.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     دخلت على
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  إثر ذلك كلمات مثل الجبر
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algebra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  والصفر
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  إلى اللغات
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     اللاتينية وترجمه
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  بعد ذلك بقليل جيراردو الكريموني الساكن في طليطلة، متبوعا في ذلك بترجمة ثالثة قام بها الإيطالي غيوم دي لونا. استُعملت ترجمة روبرت مِن تشستر
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الكتاب الرئيسي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  في الرياضيات إلى حدود القرن السادس عشر في الجامعات الأوروبية.<br><br></div></span>

# %%
doc2 = nlp(text)

for sent in doc2.sents:
    docx = nlp(sent.text)
    if docx.ents:
        displacy.render(docx, style='ent', jupyter=True)
    else:
        print(docx.text)
# Out:
# و عبد الله محمد بن موسى الخوارزمي عالم رياضيات وفلك وجغرافيا مسلم.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     يكنى باسم الخوارزمي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  وأبي جعفر.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     قيل أنه ولد حوالي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  164هـ 781م (وهو غير مؤكد) وقيل
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     أنه توفي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  بعد
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     232 هـ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  أي (بعد
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     847
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# م).</div></span>
# يعتبر من أوائل علماء الرياضيات المسلمين
# حيث ساهمت أعماله بدور كبير في تقدم الرياضيات في عصره.
# اتصل بالخليفة
# العباسي المأمون
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">وعمل في بيت الحكمة في بغداد
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     وكسب ثقة الخليفة
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  إذ ولاه المأمون بيت الحكمة كما عهد إليه برسم خارطة للأرض عمل
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     فيها أكثر
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  من سبعين جغرافيا.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     قبل وفاته
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  في
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     850 م/232 هـ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  كان الخوارزمي قد ترك العديد من المؤلفات في
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     علوم الرياضيات والفلك
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  والجغرافيا
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ومن
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  أهمها كتاب المختصر في حساب الجبر والمقابلة
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الذي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  يعد أهم كتبه.<br><br></div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ترجم
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الكتابَ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  إلى اللغة اللاتينية حوالي عام
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1145
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  م العالم روبرت مِن تشستر.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     دخلت على
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  إثر ذلك كلمات مثل الجبر
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Algebra
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  والصفر
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zero
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  إلى اللغات
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     اللاتينية وترجمه
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  بعد ذلك بقليل جيراردو الكريموني الساكن في طليطلة، متبوعا في ذلك بترجمة ثالثة قام بها الإيطالي غيوم دي لونا.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">استُعملت ترجمة روبرت مِن تشستر
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     الكتاب الرئيسي
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  في</div></span>
# الرياضيات إلى حدود القرن السادس عشر في الجامعات الأوروبية.
